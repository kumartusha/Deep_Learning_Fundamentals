# %% [markdown]
# # Multi Level Perceptron

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
#  Load the dataset.
dataset = pd.read_csv("churn_modeling.csv")
dataset.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1
# 3               0         93826.63       0
# 4               1         79084.10       0

# %%
dataset.isnull().sum()
#  we dont have any kind of the null valueinto the dataset.
# Out:
# CreditScore        0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
input_data = dataset.iloc[:, :-1]
output_score = dataset.iloc[:, -1]

# %%
# print(input_data.head())
print(output_score.head())
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
# Split the data into the train test split.
x_train, x_test, y_train, y_test = train_test_split(input_data,output_score, test_size=0.2 , random_state=42)

# %%
print(input_data.shape, x_train.shape, x_test.shape)
# Out:
# (10000, 8) (8000, 8) (2000, 8)

# %%
#  Scaling the dataset.
st = StandardScaler()

# %%
st.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train = pd.DataFrame(st.transform(x_train), columns = x_train.columns)
x_test = pd.DataFrame(st.transform(x_test), columns= x_test.columns)

# %%
x_train
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0        0.356500 -0.655786  0.345680 -1.218471       0.808436   0.649203
# 1       -0.203898  0.294938 -0.348369  0.696838       0.808436   0.649203
# 2       -0.961472 -1.416365 -0.695393  0.618629      -0.916688   0.649203
# 3       -0.940717 -1.131148  1.386753  0.953212      -0.916688   0.649203
# 4       -1.397337  1.625953  1.386753  1.057449      -0.916688  -1.540351
# ...           ...       ...       ...       ...            ...        ...
# 7995     1.207474  1.435808  1.039728 -0.102301      -0.916688   0.649203
# 7996     0.314989  1.816097 -1.389442 -1.218471      -0.916688   0.649203
# 7997     0.865009 -0.085351 -1.389442 -1.218471       2.533560  -1.540351
# 7998     0.159323  0.390011  1.039728  1.827259      -0.916688   0.649203
# 7999     0.470655  1.150590 -1.389442  1.149720      -0.916688   0.649203
#
#       IsActiveMember  EstimatedSalary
# 0           0.974817         1.367670
# 1           0.974817         1.661254
# 2          -1.025834        -0.252807
# 3          -1.025834         0.915393
# 4          -1.025834        -1.059600
# ...              ...              ...
# 7995        0.974817        -0.539860
# 7996        0.974817        -1.733882
# 7997       -1.025834        -0.142765
# 7998       -1.025834        -0.050826
# 7999        0.974817        -0.814568
#
# [8000 rows x 8 columns]

# %%
#  Import the modules for the deep learning.
import tensorflow
from keras.layers import Dense
from keras.models import Sequential

# %%
ann = Sequential()

# %%
ann.add(Dense(6, input_dim = 8, activation="relu"))
ann.add(Dense(4, activation="relu"))
ann.add(Dense(2, activation="relu"))
ann.add(Dense(1, activation="sigmoid"))
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
ann.compile(optimizer='adam', loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
ann.fit(x_train, y_train, batch_size=100,epochs = 50)
# Out:
# Epoch 1/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.7926 - loss: 0.6615
# Epoch 2/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7991 - loss: 0.5821
# Epoch 3/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7926 - loss: 0.5322
# Epoch 4/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7922 - loss: 0.4985
# Epoch 5/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7878 - loss: 0.4749
# Epoch 6/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7948 - loss: 0.4459
# Epoch 7/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8016 - loss: 0.4157
# Epoch 8/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7984 - loss: 0.4070
# Epoch 9/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7927 - loss: 0.4070
# Epoch 10/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7993 - loss: 0.3945
# Epoch 11/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7972 - loss: 0.3960
# Epoch 12/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8078 - loss: 0.3810
# Epoch 13/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8199 - loss: 0.3848
# Epoch 14/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8452 - loss: 0.3740
# Epoch 15/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8510 - loss: 0.3806
# Epoch 16/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8499 - loss: 0.3821
# Epoch 17/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8523 - loss: 0.3697
# Epoch 18/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8565 - loss: 0.3707
# Epoch 19/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8502 - loss: 0.3780
# Epoch 20/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8459 - loss: 0.3834
# Epoch 21/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8548 - loss: 0.3729
# Epoch 22/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8571 - loss: 0.3659
# Epoch 23/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8554 - loss: 0.3690
# Epoch 24/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8559 - loss: 0.3666
# Epoch 25/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8464 - loss: 0.3817
# Epoch 26/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8531 - loss: 0.3685
# Epoch 27/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8557 - loss: 0.3595
# Epoch 28/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8539 - loss: 0.3709
# Epoch 29/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8592 - loss: 0.3553
# Epoch 30/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8535 - loss: 0.3702
# Epoch 31/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8575 - loss: 0.3545
# Epoch 32/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8548 - loss: 0.3691
# Epoch 33/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8586 - loss: 0.3577
# Epoch 34/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8571 - loss: 0.3555
# Epoch 35/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8610 - loss: 0.3551
# Epoch 36/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8551 - loss: 0.3552
# Epoch 37/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8523 - loss: 0.3661
# Epoch 38/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8606 - loss: 0.3537
# Epoch 39/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8564 - loss: 0.3584
# Epoch 40/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8555 - loss: 0.3587
# Epoch 41/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8612 - loss: 0.3427
# Epoch 42/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8609 - loss: 0.3476
# Epoch 43/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8512 - loss: 0.3617
# Epoch 44/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8567 - loss: 0.3559
# Epoch 45/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8546 - loss: 0.3567
# Epoch 46/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8576 - loss: 0.3542
# Epoch 47/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8599 - loss: 0.3540
# Epoch 48/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8595 - loss: 0.3515
# Epoch 49/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8527 - loss: 0.3630
# Epoch 50/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8626 - loss: 0.3442

# %%
# Check the training accuracy for the model 
training_data_pred = ann.predict(x_train)
#  thw data we have in the 0 to 1 format due to the sigmoid logisticc function.

training_data_pred_data = []
for i in training_data_pred:
    if i[0] > 0.5:
        training_data_pred_data.append(1)
    else:
        training_data_pred_data.append(0)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# Check the testing accuracy for the model 
testing_data_pred = ann.predict(x_test)
#  thw data we have in the 0 to 1 format due to the sigmoid logisticc function.

testing_data_pred_data = []
for i in testing_data_pred:
    if i[0] > 0.5:
        testing_data_pred_data.append(1)
    else:
        testing_data_pred_data.append(0)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
print(accuracy_score(testing_data_pred_data, y_test) * 100)
# Out:
# 85.55

# %%
print(accuracy_score(training_data_pred_data, y_train) * 100)
# Out:
# 85.75

# %%
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0       -0.577496 -0.655786 -0.695393  0.329937       0.808436  -1.540351
# 1       -0.297297  0.390011 -1.389442 -1.218471       0.808436   0.649203
# 2       -0.525607  0.485083 -0.348369 -1.218471       0.808436   0.649203
# 3       -1.511492  1.911170  1.039728  0.689272       0.808436   0.649203
# 4       -0.951094 -1.131148  0.692704  0.782839      -0.916688   0.649203
# ...           ...       ...       ...       ...            ...        ...
# 1995    -0.515230  1.340735 -0.001345  0.354911      -0.916688  -1.540351
# 1996    -0.442586 -1.321293  1.733777 -1.218471      -0.916688  -1.540351
# 1997     0.813120  0.770301  0.692704 -1.218471      -0.916688   0.649203
# 1998     0.418766 -0.941003 -0.348369 -1.218471      -0.916688   0.649203
# 1999    -0.245409  0.009721 -1.389442  0.628256      -0.916688   0.649203
#
#       IsActiveMember  EstimatedSalary
# 0          -1.025834        -1.019605
# 1           0.974817         0.798883
# 2          -1.025834        -0.727980
# 3           0.974817         1.221387
# 4           0.974817         0.247560
# ...              ...              ...
# 1995        0.974817        -0.963100
# 1996        0.974817         0.164545
# 1997       -1.025834        -1.165916
# 1998       -1.025834        -0.411635
# 1999        0.974817         0.125932
#
# [2000 rows x 8 columns]

# %%
#  Check the model performance for the new data.
new_data = np.asarray((-0.577496	,-0.655786,	-0.695393,	0.329937	,0.808436	,-1.540351	,-1.025834	,-1.019605)).reshape(1,-1)

new_data_pred = ann.predict(new_data)
#  thw data we have in the 0 to 1 format due to the sigmoid logisticc function.

new_data = []
for i in new_data_pred:
    if i[0] > 0.5:
        new_data.append(1)
    else:
        new_data.append(0)

print(new_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# [0]

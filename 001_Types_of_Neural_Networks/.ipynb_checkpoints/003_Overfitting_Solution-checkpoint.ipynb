# %% [markdown]
# # Overfitting Solution for the Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
#  Load the dataset.
dataset = pd.read_csv("churn_modeling.csv")
dataset.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1
# 3               0         93826.63       0
# 4               1         79084.10       0

# %%
dataset.isnull().sum()
#  we dont have any kind of the null valueinto the dataset.
# Out:
# CreditScore        0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
input_data = dataset.iloc[:, :-1]
output_score = dataset.iloc[:, -1]

# %%
# print(input_data.head())
print(output_score.head())
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
# Split the data into the train test split.
x_train, x_test, y_train, y_test = train_test_split(input_data,output_score, test_size=0.2 , random_state=2)

# %%
print(input_data.shape, x_train.shape, x_test.shape)
# Out:
# (10000, 8) (8000, 8) (2000, 8)

# %%
#  Scaling the dataset.
st = StandardScaler()

# %%
st.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train = pd.DataFrame(st.transform(x_train), columns = x_train.columns)
x_test = pd.DataFrame(st.transform(x_test), columns= x_test.columns)

# %%
x_train
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0        1.277546 -1.232643 -0.012743 -1.239615       0.811186   0.649203
# 1       -0.499595  0.284106  0.332830  1.306219      -0.902437   0.649203
# 2        0.678277 -0.095081 -1.395034 -1.239615       0.811186   0.649203
# 3       -0.509927 -1.801425  1.369548  0.728185       0.811186   0.649203
# 4       -0.675242  1.421668  1.023976  0.160226      -0.902437   0.649203
# ...           ...       ...       ...       ...            ...        ...
# 7995    -1.615474 -0.095081  0.678403 -1.239615       0.811186   0.649203
# 7996    -0.602917 -1.232643 -0.358316  0.449125       0.811186   0.649203
# 7997     2.062794 -0.284675 -0.703889 -1.239615       0.811186   0.649203
# 7998    -1.026538  1.421668 -0.012743  0.415569      -0.902437   0.649203
# 7999     0.037680 -1.043050  0.678403 -1.239615       0.811186   0.649203
#
#       IsActiveMember  EstimatedSalary
# 0           0.965108        -0.620271
# 1           0.965108         0.546598
# 2           0.965108        -0.013208
# 3          -1.036153        -0.236775
# 4           0.965108        -0.783044
# ...              ...              ...
# 7995        0.965108        -1.636736
# 7996       -1.036153         0.562495
# 7997       -1.036153         1.643567
# 7998       -1.036153         1.324744
# 7999       -1.036153         0.884130
#
# [8000 rows x 8 columns]

# %%
#  Import the modules for the deep learning.
import tensorflow
from keras.layers import Dense
from keras.regularizers import L2
from keras.callbacks import EarlyStopping
from keras.models import Sequential

# %%
ann = Sequential()

# %%
ann.add(Dense(6, input_dim = 8, activation="relu", kernel_regularizer=L2(l2=0.01)))
ann.add(Dense(4, activation="relu"))
ann.add(Dense(2, activation="relu"))
ann.add(Dense(1, activation="sigmoid"))

# %%
ann.compile(optimizer='adam', loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
ann.fit(x_train, y_train, batch_size=100,epochs = 50, validation_data=(x_test, y_test), callbacks=EarlyStopping())
# Out:
# Epoch 1/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7942 - loss: 0.7455 - val_accuracy: 0.8085 - val_loss: 0.6754
# Epoch 2/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7936 - loss: 0.6570 - val_accuracy: 0.8085 - val_loss: 0.5793
# Epoch 3/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7839 - loss: 0.5840 - val_accuracy: 0.8085 - val_loss: 0.5306
# Epoch 4/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8010 - loss: 0.5360 - val_accuracy: 0.8085 - val_loss: 0.5165
# Epoch 5/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7885 - loss: 0.5404 - val_accuracy: 0.8085 - val_loss: 0.5073
# Epoch 6/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7898 - loss: 0.5305 - val_accuracy: 0.8085 - val_loss: 0.5007
# Epoch 7/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7911 - loss: 0.5222 - val_accuracy: 0.8085 - val_loss: 0.4937
# Epoch 8/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7927 - loss: 0.5135 - val_accuracy: 0.8085 - val_loss: 0.4882
# Epoch 9/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7968 - loss: 0.5023 - val_accuracy: 0.8085 - val_loss: 0.4844
# Epoch 10/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7940 - loss: 0.5026 - val_accuracy: 0.8085 - val_loss: 0.4813
# Epoch 11/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7851 - loss: 0.5108 - val_accuracy: 0.8085 - val_loss: 0.4783
# Epoch 12/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7964 - loss: 0.4924 - val_accuracy: 0.8085 - val_loss: 0.4757
# Epoch 13/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7851 - loss: 0.5033 - val_accuracy: 0.8085 - val_loss: 0.4714
# Epoch 14/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7921 - loss: 0.4888 - val_accuracy: 0.8085 - val_loss: 0.4639
# Epoch 15/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7901 - loss: 0.4809 - val_accuracy: 0.8085 - val_loss: 0.4540
# Epoch 16/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7901 - loss: 0.4712 - val_accuracy: 0.8085 - val_loss: 0.4435
# Epoch 17/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7894 - loss: 0.4622 - val_accuracy: 0.8085 - val_loss: 0.4322
# Epoch 18/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7919 - loss: 0.4467 - val_accuracy: 0.8085 - val_loss: 0.4221
# Epoch 19/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7978 - loss: 0.4292 - val_accuracy: 0.8085 - val_loss: 0.4162
# Epoch 20/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7948 - loss: 0.4279 - val_accuracy: 0.8085 - val_loss: 0.4070
# Epoch 21/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7920 - loss: 0.4229 - val_accuracy: 0.8085 - val_loss: 0.4060
# Epoch 22/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7845 - loss: 0.4201 - val_accuracy: 0.8085 - val_loss: 0.4008
# Epoch 23/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7917 - loss: 0.4130 - val_accuracy: 0.8085 - val_loss: 0.3992
# Epoch 24/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7881 - loss: 0.4095 - val_accuracy: 0.8085 - val_loss: 0.4011

# %%
ann.history.history
# Out:
# {'accuracy': [0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951],
#  'loss': [0.7243243455886841,
#   0.6344678401947021,
#   0.5658779144287109,
#   0.5424872040748596,
#   0.5319889783859253,
#   0.5243708491325378,
#   0.5174524784088135,
#   0.510971188545227,
#   0.5063253045082092,
#   0.5027204751968384,
#   0.49931249022483826,
#   0.4959183633327484,
#   0.4923841059207916,
#   0.48588988184928894,
#   0.47575628757476807,
#   0.4638473689556122,
#   0.45072147250175476,
#   0.4389168322086334,
#   0.42842841148376465,
#   0.4192793667316437,
#   0.41416746377944946,
#   0.41256171464920044,
#   0.4091494083404541,
#   0.4078569710254669],
#  'val_accuracy': [0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683],
#  'val_loss': [0.6753948926925659,
#   0.5793489813804626,
#   0.530594527721405,
#   0.5164620280265808,
#   0.5072764754295349,
#   0.5006529092788696,
#   0.49373939633369446,
#   0.4882444143295288,
#   0.4843797981739044,
#   0.4813133180141449,
#   0.47825244069099426,
#   0.47566694021224976,
#   0.47138074040412903,
#   0.46392595767974854,
#   0.45403531193733215,
#   0.44350796937942505,
#   0.4321841299533844,
#   0.4220956861972809,
#   0.4161989986896515,
#   0.4070424735546112,
#   0.40599367022514343,
#   0.4007580578327179,
#   0.39917469024658203,
#   0.4010860025882721]}

# %%
train_accuracy = ann.history.history["accuracy"]
test_accuracy = ann.history.history["val_accuracy"]

# %%
plt.plot([i for i in range(1,25)], train_accuracy)
plt.plot([i for i in range(1,25)], test_accuracy, c = 'red')
plt.show()

# print(train_accuracy)
# print(test_accuracy)

# %%
# Check the training accuracy for the model 
training_data_pred = ann.predict(x_train)
#  thw data we have in the 0 to 1 format due to the sigmoid logisticc function.

training_data_pred_data = []
for i in training_data_pred:
    if i[0] > 0.5:
        training_data_pred_data.append(1)
    else:
        training_data_pred_data.append(0)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
# Check the testing accuracy for the model 
testing_data_pred = ann.predict(x_test)
#  thw data we have in the 0 to 1 format due to the sigmoid logisticc function.

testing_data_pred_data = []
for i in testing_data_pred:
    if i[0] > 0.5:
        testing_data_pred_data.append(1)
    else:
        testing_data_pred_data.append(0)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
print(accuracy_score(testing_data_pred_data, y_test) * 100)
# Out:
# 80.85

# %%
print(accuracy_score(training_data_pred_data, y_train) * 100)
# Out:
# 79.325

# %%
#  Check the model performance for the new data.
new_data = np.asarray((-0.577496	,-0.655786,	-0.695393,	0.329937	,0.808436	,-1.540351	,-1.025834	,-1.019605)).reshape(1,-1)

new_data_pred = ann.predict(new_data)
#  thw data we have in the 0 to 1 format due to the sigmoid logisticc function.

new_data = []
for i in new_data_pred:
    if i[0] > 0.5:
        new_data.append(1)
    else:
        new_data.append(0)

print(new_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# [0]

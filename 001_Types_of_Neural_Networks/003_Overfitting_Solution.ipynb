# %% [markdown]
# # Overfitting Solution for the Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
#  Load the dataset.
dataset = pd.read_csv("churn_modeling.csv")
dataset.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1
# 3               0         93826.63       0
# 4               1         79084.10       0

# %%
dataset.isnull().sum()
#  we dont have any kind of the null valueinto the dataset.
# Out:
# CreditScore        0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
input_data = dataset.iloc[:, :-1]
output_score = dataset.iloc[:, -1]

# %%
# print(input_data.head())
print(output_score.head())
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
# Split the data into the train test split.
x_train, x_test, y_train, y_test = train_test_split(input_data,output_score, test_size=0.2 , random_state=2)

# %%
print(input_data.shape, x_train.shape, x_test.shape)
# Out:
# (10000, 8) (8000, 8) (2000, 8)

# %%
#  Scaling the dataset.
st = StandardScaler()

# %%
st.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train = pd.DataFrame(st.transform(x_train), columns = x_train.columns)
x_test = pd.DataFrame(st.transform(x_test), columns= x_test.columns)

# %%
x_train
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0        1.277546 -1.232643 -0.012743 -1.239615       0.811186   0.649203
# 1       -0.499595  0.284106  0.332830  1.306219      -0.902437   0.649203
# 2        0.678277 -0.095081 -1.395034 -1.239615       0.811186   0.649203
# 3       -0.509927 -1.801425  1.369548  0.728185       0.811186   0.649203
# 4       -0.675242  1.421668  1.023976  0.160226      -0.902437   0.649203
# ...           ...       ...       ...       ...            ...        ...
# 7995    -1.615474 -0.095081  0.678403 -1.239615       0.811186   0.649203
# 7996    -0.602917 -1.232643 -0.358316  0.449125       0.811186   0.649203
# 7997     2.062794 -0.284675 -0.703889 -1.239615       0.811186   0.649203
# 7998    -1.026538  1.421668 -0.012743  0.415569      -0.902437   0.649203
# 7999     0.037680 -1.043050  0.678403 -1.239615       0.811186   0.649203
#
#       IsActiveMember  EstimatedSalary
# 0           0.965108        -0.620271
# 1           0.965108         0.546598
# 2           0.965108        -0.013208
# 3          -1.036153        -0.236775
# 4           0.965108        -0.783044
# ...              ...              ...
# 7995        0.965108        -1.636736
# 7996       -1.036153         0.562495
# 7997       -1.036153         1.643567
# 7998       -1.036153         1.324744
# 7999       -1.036153         0.884130
#
# [8000 rows x 8 columns]

# %%
#  Import the modules for the deep learning.
import tensorflow
from keras.layers import Dense
from keras.regularizers import L2
from keras.callbacks import EarlyStopping
from keras.models import Sequential

# %%
ann = Sequential()

# %%
ann.add(Dense(6, input_dim = 8, activation="relu", kernel_regularizer=L2(l2=0.01)))
ann.add(Dense(4, activation="relu"))
ann.add(Dense(2, activation="relu"))
ann.add(Dense(1, activation="sigmoid"))
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
ann.compile(optimizer='adam', loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
ann.fit(x_train, y_train, batch_size=100,epochs = 50, validation_data=(x_test, y_test), callbacks=EarlyStopping())
# Out:
# Epoch 1/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7884 - loss: 0.7583 - val_accuracy: 0.8085 - val_loss: 0.6919
# Epoch 2/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7974 - loss: 0.6708 - val_accuracy: 0.8085 - val_loss: 0.5939
# Epoch 3/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7894 - loss: 0.5849 - val_accuracy: 0.8085 - val_loss: 0.5154
# Epoch 4/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7933 - loss: 0.5175 - val_accuracy: 0.8085 - val_loss: 0.4776
# Epoch 5/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7926 - loss: 0.4859 - val_accuracy: 0.8085 - val_loss: 0.4594
# Epoch 6/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7939 - loss: 0.4699 - val_accuracy: 0.8085 - val_loss: 0.4491
# Epoch 7/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7910 - loss: 0.4625 - val_accuracy: 0.8085 - val_loss: 0.4419
# Epoch 8/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7896 - loss: 0.4558 - val_accuracy: 0.8085 - val_loss: 0.4362
# Epoch 9/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7919 - loss: 0.4446 - val_accuracy: 0.8085 - val_loss: 0.4311
# Epoch 10/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7877 - loss: 0.4435 - val_accuracy: 0.8085 - val_loss: 0.4257
# Epoch 11/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7967 - loss: 0.4309 - val_accuracy: 0.8085 - val_loss: 0.4206
# Epoch 12/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7915 - loss: 0.4324 - val_accuracy: 0.8085 - val_loss: 0.4155
# Epoch 13/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7912 - loss: 0.4202 - val_accuracy: 0.8085 - val_loss: 0.4099
# Epoch 14/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7928 - loss: 0.4169 - val_accuracy: 0.8085 - val_loss: 0.4048
# Epoch 15/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7964 - loss: 0.4085 - val_accuracy: 0.8085 - val_loss: 0.4022
# Epoch 16/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7902 - loss: 0.4134 - val_accuracy: 0.8085 - val_loss: 0.3976
# Epoch 17/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8024 - loss: 0.3931 - val_accuracy: 0.8490 - val_loss: 0.3961
# Epoch 18/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8358 - loss: 0.4127 - val_accuracy: 0.8495 - val_loss: 0.3931
# Epoch 19/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8483 - loss: 0.3922 - val_accuracy: 0.8505 - val_loss: 0.3915
# Epoch 20/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8420 - loss: 0.3971 - val_accuracy: 0.8530 - val_loss: 0.3881
# Epoch 21/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8463 - loss: 0.3894 - val_accuracy: 0.8505 - val_loss: 0.3877
# Epoch 22/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8448 - loss: 0.3959 - val_accuracy: 0.8495 - val_loss: 0.3854
# Epoch 23/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8446 - loss: 0.3946 - val_accuracy: 0.8555 - val_loss: 0.3852
# Epoch 24/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8474 - loss: 0.3917 - val_accuracy: 0.8535 - val_loss: 0.3839
# Epoch 25/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8549 - loss: 0.3827 - val_accuracy: 0.8545 - val_loss: 0.3819
# Epoch 26/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8441 - loss: 0.3957 - val_accuracy: 0.8570 - val_loss: 0.3813
# Epoch 27/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8558 - loss: 0.3747 - val_accuracy: 0.8550 - val_loss: 0.3812
# Epoch 28/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8515 - loss: 0.3778 - val_accuracy: 0.8560 - val_loss: 0.3808
# Epoch 29/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8450 - loss: 0.3902 - val_accuracy: 0.8555 - val_loss: 0.3785
# Epoch 30/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8518 - loss: 0.3786 - val_accuracy: 0.8545 - val_loss: 0.3805

# %%
ann.history.history
# Out:
# {'accuracy': [0.7931249737739563,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.7932500243186951,
#   0.8078749775886536,
#   0.840749979019165,
#   0.843500018119812,
#   0.8457499742507935,
#   0.8482499718666077,
#   0.8492500185966492,
#   0.8488749861717224,
#   0.8521249890327454,
#   0.8522499799728394,
#   0.8513749837875366,
#   0.8527500033378601,
#   0.8511250019073486,
#   0.8519999980926514,
#   0.8519999980926514],
#  'loss': [0.7386475205421448,
#   0.6512932777404785,
#   0.5637952089309692,
#   0.5087189674377441,
#   0.4795759916305542,
#   0.4649811387062073,
#   0.45617812871932983,
#   0.4496708810329437,
#   0.4442405700683594,
#   0.43896302580833435,
#   0.4336870610713959,
#   0.4284549951553345,
#   0.42268189787864685,
#   0.41669848561286926,
#   0.4100853502750397,
#   0.4051665663719177,
#   0.4009038805961609,
#   0.39820489287376404,
#   0.39479848742485046,
#   0.3920096755027771,
#   0.3902820348739624,
#   0.38858067989349365,
#   0.3864925503730774,
#   0.38501283526420593,
#   0.38387441635131836,
#   0.3827401399612427,
#   0.38175034523010254,
#   0.38010865449905396,
#   0.3797096312046051,
#   0.37918946146965027],
#  'val_accuracy': [0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8084999918937683,
#   0.8489999771118164,
#   0.8495000004768372,
#   0.8504999876022339,
#   0.8529999852180481,
#   0.8504999876022339,
#   0.8495000004768372,
#   0.8554999828338623,
#   0.8535000085830688,
#   0.8544999957084656,
#   0.8569999933242798,
#   0.8550000190734863,
#   0.8560000061988831,
#   0.8554999828338623,
#   0.8544999957084656],
#  'val_loss': [0.6918518543243408,
#   0.5939173698425293,
#   0.5154259204864502,
#   0.47755464911460876,
#   0.45944708585739136,
#   0.44914281368255615,
#   0.44192269444465637,
#   0.4361969828605652,
#   0.4310687184333801,
#   0.4256846308708191,
#   0.4205920994281769,
#   0.4155389368534088,
#   0.4098643660545349,
#   0.4047672748565674,
#   0.4021768569946289,
#   0.3976496756076813,
#   0.39614611864089966,
#   0.39305585622787476,
#   0.39150312542915344,
#   0.3880552351474762,
#   0.3876664638519287,
#   0.3854354918003082,
#   0.3852064311504364,
#   0.3838783800601959,
#   0.3819059431552887,
#   0.3813210129737854,
#   0.3812013566493988,
#   0.3808366060256958,
#   0.3785400688648224,
#   0.3805443346500397]}

# %%
train_accuracy = ann.history.history["accuracy"]
test_accuracy = ann.history.history["val_accuracy"]

# %%
plt.plot([i for i in range(1,31)], train_accuracy)
plt.plot([i for i in range(1,31)], test_accuracy, c = 'red')
plt.show()

# print(train_accuracy)
# print(test_accuracy)

# %%
# Check the training accuracy for the model 
training_data_pred = ann.predict(x_train)
#  thw data we have in the 0 to 1 format due to the sigmoid logisticc function.

training_data_pred_data = []
for i in training_data_pred:
    if i[0] > 0.5:
        training_data_pred_data.append(1)
    else:
        training_data_pred_data.append(0)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# Check the testing accuracy for the model 
testing_data_pred = ann.predict(x_test)
#  thw data we have in the 0 to 1 format due to the sigmoid logisticc function.

testing_data_pred_data = []
for i in testing_data_pred:
    if i[0] > 0.5:
        testing_data_pred_data.append(1)
    else:
        testing_data_pred_data.append(0)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
print(accuracy_score(testing_data_pred_data, y_test) * 100)
# Out:
# 85.45

# %%
print(accuracy_score(training_data_pred_data, y_train) * 100)
# Out:
# 85.2125

# %%
#  Check the model performance for the new data.
new_data = np.asarray((-0.577496	,-0.655786,	-0.695393,	0.329937	,0.808436	,-1.540351	,-1.025834	,-1.019605)).reshape(1,-1)

new_data_pred = ann.predict(new_data)
#  thw data we have in the 0 to 1 format due to the sigmoid logisticc function.

new_data = []
for i in new_data_pred:
    if i[0] > 0.5:
        new_data.append(1)
    else:
        new_data.append(0)

print(new_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# [0]
